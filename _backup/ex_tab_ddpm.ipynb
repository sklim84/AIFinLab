# %%
# %cd baselines/tab-ddpm
# Out:
# [Errno 2] No such file or directory: 'baselines/tab-ddpm'
# /home/bigdyl/economics/AIFinLab/baselines/tab-ddpm
# /home/bigdyl/anaconda3/envs/aifinlab/lib/python3.9/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
# !wget "https://www.dropbox.com/s/rpckvcs3vx7j605/data.tar?dl=0" -O data.tar
# !tar -xvf data.tar
# Out:
# --2024-06-02 08:58:08--  https://www.dropbox.com/s/rpckvcs3vx7j605/data.tar?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.84.18, 2620:100:6034:18::a27d:5412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.84.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /scl/fi/nfwljijpqzjsxbm8znesl/data.tar?rlkey=yzcncwye2jmua9b2o1pb1zj0m&dl=0 [following]
# --2024-06-02 08:58:11--  https://www.dropbox.com/scl/fi/nfwljijpqzjsxbm8znesl/data.tar?rlkey=yzcncwye2jmua9b2o1pb1zj0m&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc37b717e7618b2b33620a6ee37c.dl.dropboxusercontent.com/cd/0/inline/CUBsjtBrwTE4F3vIfs_deWAuX9QY7xRVCw6Y8kjGjll4C7SmLBDkiUNCaKF3kgGCsub1JE1Kgzx0X3BwCnCbHQGf-k4ck550WvQm1QwXwYemuGx4OxdZUatxMgvq3ZKkI-FV1GlgTfWLLq1Yk3xUvd3u/file# [following]
# ...

# %%
# Out:
# Traceback (most recent call last):
#   File "scripts/tune_ddpm.py", line 2, in <module>
#     import lib
# ModuleNotFoundError: No module named 'lib'
